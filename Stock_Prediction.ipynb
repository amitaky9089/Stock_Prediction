# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pandas import read_csv
filename='NSE-TATAGLOBAL.csv'
data=read_csv(filename)

# %%
data
# Out:
#             Date    Open    High     Low    Last   Close  Total Trade Quantity  Turnover (Lacs)
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914          7162.35
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859         11859.95
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909          5248.60
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368          5503.90
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509          7999.55
# ...          ...     ...     ...     ...     ...     ...                   ...              ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65                586100           694.98
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60                658440           780.01
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65                281312           340.31
# ...

# %%
data.head(10)
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914          7162.35
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859         11859.95
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909          5248.60
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368          5503.90
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509          7999.55
# 5  2018-09-21  235.00  237.00  227.95  233.75  234.60               5395319         12589.59
# 6  2018-09-19  235.95  237.20  233.45  234.60  234.90               1362058          3202.78
# 7  2018-09-18  237.90  239.25  233.50  235.50  235.05               2614794          6163.70
# 8  2018-09-17  233.15  238.00  230.25  236.40  236.60               3170894          7445.41
# ...

# %%
data = data.iloc[::-1].reset_index(drop=True)
data
# Out:
#             Date    Open    High     Low    Last   Close  Total Trade Quantity  Turnover (Lacs)
# 0     2010-07-21  122.10  123.00  121.05  121.10  121.55                658666           803.56
# 1     2010-07-22  120.30  122.00  120.25  120.75  120.90                293312           355.17
# 2     2010-07-23  121.80  121.95  120.25  120.35  120.65                281312           340.31
# 3     2010-07-26  120.10  121.00  117.10  117.10  117.60                658440           780.01
# 4     2010-07-27  117.60  119.50  112.00  118.80  118.65                586100           694.98
# ...          ...     ...     ...     ...     ...     ...                   ...              ...
# 2030  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509          7999.55
# 2031  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368          5503.90
# 2032  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909          5248.60
# ...

# %%
plt.figure(figsize=(16,8))
plt.plot(data['Close'] ,label='Closing Price')

# %%
max_val=data['Close'].max()
min_val=data['Close'].min()
max_val,min_val
# Out:
# (325.75, 80.95)

# %%
data['Open - Close']=data['Open']-data['Close']
data['High - Low']=data['High']-data['Low']
data=data.dropna()

# %%
data
# Out:
#             Date    Open    High     Low    Last   Close  Total Trade Quantity  Turnover (Lacs)  Open - Close  High - Low
# 0     2010-07-21  122.10  123.00  121.05  121.10  121.55                658666           803.56          0.55        1.95
# 1     2010-07-22  120.30  122.00  120.25  120.75  120.90                293312           355.17         -0.60        1.75
# 2     2010-07-23  121.80  121.95  120.25  120.35  120.65                281312           340.31          1.15        1.70
# 3     2010-07-26  120.10  121.00  117.10  117.10  117.60                658440           780.01          2.50        3.90
# 4     2010-07-27  117.60  119.50  112.00  118.80  118.65                586100           694.98         -1.05        7.50
# ...          ...     ...     ...     ...     ...     ...                   ...              ...           ...         ...
# 2030  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509          7999.55          0.25        8.45
# ...

# %%
# X=data[['Open - Close' , 'High - Low']]
X=data[['Open', 'High', 'Low', 'Last']]
X
# Out:
#         Open    High     Low    Last
# 0     122.10  123.00  121.05  121.10
# 1     120.30  122.00  120.25  120.75
# 2     121.80  121.95  120.25  120.35
# 3     120.10  121.00  117.10  117.10
# 4     117.60  119.50  112.00  118.80
# ...      ...     ...     ...     ...
# 2030  233.55  239.20  230.75  234.00
# 2031  233.30  236.75  232.00  236.25
# 2032  240.00  240.00  232.50  235.00
# 2033  234.55  236.80  231.10  233.80
# 2034  234.05  235.95  230.20  233.50
#
# [2035 rows x 4 columns]

# %%
print(X.dtypes)
# Out:
# Open    float64
# High    float64
# Low     float64
# Last    float64
# dtype: object

# %%
"+1 indicates to buy and -1 indicates to sell"
# Out:
# '+1 indicates to buy and -1 indicates to sell'

# %%
# y=np.where(data['Close'].shift(-1)>data['Close'],1,-1)

# %%
y=data['Close']

# %%
y
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

# %%
params={'n_neighbors':[2,5,8,10,15,18,20,25]}
knn=KNeighborsRegressor()
model=GridSearchCV(knn,params,cv=5)
model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [2, 5, 8, 10, 15, 18, 20, 25]})

# %%
model.best_params_
# Out:
# {'n_neighbors': 2}

# %%
y_pred=model.predict(X_test)
y_test
# Out:
# 611     160.45
# 111     109.55
# 1185    141.95
# 1510    138.85
# 771     141.65
#          ...
# 630     145.50
# 1328    132.95
# 602     168.75
# 310      87.90
# 584     164.15
# Name: Close, Length: 509, dtype: float64

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 0.6271611001964631

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.9495837426326129

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
rmse
# Out:
# 0.9744658755608699

# %%
predicted_values=pd.DataFrame({'Acutal_Output':y_test, 'Predicted_Output':y_pred})
predicted_values
# Out:
#       Acutal_Output  Predicted_Output
# 611          160.45           160.875
# 111          109.55           109.450
# 1185         141.95           142.225
# 1510         138.85           138.900
# 771          141.65           141.300
# ...             ...               ...
# 630          145.50           144.725
# 1328         132.95           133.200
# 602          168.75           169.325
# 310           87.90            88.150
# 584          164.15           167.675
#
# [509 rows x 2 columns]
